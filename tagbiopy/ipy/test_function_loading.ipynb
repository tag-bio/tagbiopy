# %% [markdown]
# # Imports

# %%
import importlib

import tagbiopy.utils

# %%
importlib.reload(tagbiopy.utils)
# Out:
# <module 'tagbiopy.utils' from '/Users/damir/code/tagbiopy/tagbiopy/utils.py'>

# %% [markdown]
# # Test file

# %%
input_file = '/Users/damir/code/protocols/cbioportal/fc-pan-can/protocols/python_hello_world.py'

# %% [markdown]
# # Work

# %%
input_file = '/Users/damir/code/protocols/cbioportal/fc-pan-can/protocols/python_hello_world.py'

# %%
input_file = '/Users/damir/code/annotation/annotation/tcga/parser.py'

# %%
# Out:
# <module 'tagbiopy.utils' from '/Users/damir/code/tagbiopy/tagbiopy/utils.py'>

# %%
m = tagbiopy.utils.load_function(input_file)
# Out:
# /Users/damir/code/protocols/cbioportal/fc-pan-can/protocols/python_hello_world.py

# %%
m
# Out:
# <function tgb.test_function(tag_data, tag_result)>

# %%
w
# Out:
# ['__annotations__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
z(None, {'a': 1})
