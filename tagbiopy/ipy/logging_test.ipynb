# %% [markdown]
# # Imports

# %%
import importlib

import sklearn

import tagbiopy.logging

# %%
import logging

# %%
importlib.reload(tagbiopy.logging)

# %% [markdown]
# # Action

# %%
logger_py_w = logging.getLogger('py.warnings')

# %%
help(py_logging.handle)

# %%
logger_py_w.hasHandlers()

# %%
logging.captureWarnings(True)

# %%
logger_py_w.hasHandlers()

# %%
logger_sklearn = sklearn.logger

# %%
logger_sklearn.handlers[0]

# %%
logger_sklearn_fix = tagbiopy.logging.fix_sklearn_logger()

# %%
logger_sklearn_fix

# %%
logger_sklearn.handlers[0]

# %%
logger_sklearn.info('No fucking way')

# %%
logger = tagbiopy.logging.initialize_logger()

# %%
p

# %%
logger.handlers

# %%
sklearn_logger.handlers[0]

# %%
dir(sklearn_logger)

# %%
_ = sklearn_logger.handlers.pop()

# %%
sklearn_logger.handlers

# %%
sklearn_logger.handlers[0] = None

# %%
sklearn_logger.info('So this is shown on the console!!!')

# %%
sklearn_logger.warning('This too')

# %%
sklearn_logger.handlers[0].close()

# %%
sklearn_logger.warning('This too')

# %%
sklearn_logger.handlers = None

# %%
import warnings

# %%
def fxn():
    warnings.warn("deprecated", DeprecationWarning)

# %%
fxn()

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fxn()

# %% [markdown]
# # Check joblib logger

# %%
import joblib

# %%
logger_joblib = joblib.logger

# %%
dir(logger_joblib)

# %%
import logging
import time
import sys

# from sklearn.externals.joblib import Parallel, delayed
from joblib import Parallel, delayed

logger = logging.getLogger()
formatter = logging.Formatter(
    '%(asctime)s %(levelname)s: %(message)s '
    '[in %(pathname)s:%(lineno)d]')
handler = logging.StreamHandler(sys.stdout)
handler.setFormatter(formatter)
logger.addHandler(handler)


def func(i):
    logger.warning(f"Function calling {i}")
    time.sleep(0.5)


with Parallel(n_jobs=4) as parallel:
    parallel(delayed(func)(i) for i in range(10))

# %%
import logging
import time
import sys

# from sklearn.externals.joblib import Parallel, delayed
from joblib import Parallel, delayed

def get_logger():
    logger = logging.getLogger()
    formatter = logging.Formatter(
        '%(asctime)s %(levelname)s: %(message)s '
        '[in %(pathname)s:%(lineno)d]')
    handler = logging.StreamHandler(sys.stdout)
    handler.setFormatter(formatter)
    logger.addHandler(handler)
    return logger


def func(i):
    logger = get_logger()
    logger.warning(f"Function calling {i}")
    time.sleep(0.5)


with Parallel(n_jobs=4) as parallel:
    parallel(delayed(func)(i) for i in range(10))

# %% [markdown]
# # Test py.warnings

# %%
py_logger = logging.getLogger('py.warnings')

# %%
py_logger.info('Wtf')
