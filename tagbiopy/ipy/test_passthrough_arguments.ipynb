# %% [markdown]
# # Imports

# %%
# %matplotlib inline

# %%
import importlib

import json
import os

import pandas as pd
import numpy as np

import requests

import tagbiopy.utils
import tagbiopy.plots

# %% [markdown]
# ## Dev: reload utils and plots

# %%
importlib.reload(tagbiopy.utils)
# Out:
# <module 'tagbiopy.utils' from '/Users/damir/code/tagbiopy/tagbiopy/utils.py'>

# %%
importlib.reload(tagbiopy.plots)
# Out:
# <module 'tagbiopy.plots' from '/Users/damir/code/tagbiopy/tagbiopy/plots.py'>

# %% [markdown]
# # CLI executable: connect_tagbio

# %%
def connect_tagbio_py(fc_packet, user_function, output_file=None, extension='jpg'):
    cli = '$HOME/code/tagbiopy/tagbiopy/bin/connect_tagbio_py.sh'
    # !{cli} -d {fc_packet} -f {user_function} -o {output_file} -t {extension}

# %% [markdown]
# # Input parameters

# %% [markdown]
# ## FC packet

# %%
fc_packet = '/var/folders/n4/p8bky4cs7rsgdn15v61ys0lc0000gn/T/6825505268130017284526705023722098084.json'

# %%
fc_packet = './15792186477358274564648592847573872763.json'

# %% [markdown]
# ## User function

# %%
def get_py_file(what='elastic_net'):
    base_dir = os.path.join(os.environ['HOME'], 'code/protocols/customers/pfizer/fc-topaz/python')
    if what == 'elastic_net':
        return os.path.join(base_dir, 'elastic_net_cross_validation.py')
    else:
        return os.path.join(base_dir, 'create_correlations_dataframe.py')

# %%
py_script = get_py_file(what='elastic_net')
user_function = tagbiopy.utils.load_function(py_script)

# %%
user_function
# Out:
# <function tgb.tagbio_elastic_net_cross_validation(tag_data: tagbiopy.utils.TagbioData, tag_result: tagbiopy.utils.TagbioResult)>

# %% [markdown]
# ### Extension

# %% [markdown]
# 'html' works with correlation graph only (so far)

# %%
extension = 'html'

# %% [markdown]
# ### Output file

# %%
output_file_from_ipy = 'tag_result_jupyter_' + tagbiopy.utils.now('_') + '.' + extension

# %% [markdown]
# # Execute in jupyter notebook

# %% [markdown]
# ## User function parameters

# %% [markdown]
# ### tag_data: tagbiopy.utils.TagbioData

# %%
tag_data = tagbiopy.utils.TagbioData(fc_packet=fc_packet)

# %%
print(tag_data.fc_packet.passthrough_arguments)

# %%
print(passthrough_args)

# %% [markdown]
# ### tag_result: tagbio.utils.TagbioResult

# %%
tag_result = tagbiopy.utils.TagbioResult(extension=extension, 
                                         path=output_file_from_ipy, 
                                         path_mutable=False)

# %%
print(tag_result)

# %% [markdown]
# ## Execute user function

# %%
# %%time

user_function(tag_data, tag_result)

# %% [markdown]
# ### Show the plot

# %%
tag_result.fig

# %% [markdown]
# # Execute on the command line

# %%
from IPython.display import HTML

# %%
output_file_from_cli = 'tag_result_cli_' + tagbiopy.utils.now('_') + '.' + extension

# %%
extension

# %%
# %%time

run_cli(fc_packet, py_script, output_file_from_cli, extension)

# %% [markdown]
# ### Show the plot

# %%
HTML(filename=output_file_from_cli)
