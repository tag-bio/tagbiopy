# %% [markdown]
# # Imports

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import importlib

import json
import os

import pandas as pd
import numpy as np

import requests

import tagbiopy.utils
import tagbiopy.plots

# %%
import plotly.graph_objects as go
import matplotlib.pyplot as plt

# %%
importlib.reload(tagbiopy.utils)
# Out:
# <module 'tagbiopy.utils' from '/Users/damir/code/tagbiopy/tagbiopy/utils.py'>

# %%
importlib.reload(tagbiopy.plots)
# Out:
# <module 'tagbiopy.plots' from '/Users/damir/code/tagbiopy/tagbiopy/plots.py'>

# %%
import datetime

# %%
def now():
    return datetime.datetime.now().strftime('%X').replace(':', '-')

# %% [markdown]
# # Project

# %% [markdown]
# ## FC jsons

# %%
filename_download = '/var/folders/n4/p8bky4cs7rsgdn15v61ys0lc0000gn/T/6219469430113904641407114889491759794.json'

# %%
filename_embed = '/var/folders/n4/p8bky4cs7rsgdn15v61ys0lc0000gn/T/80122839451031736325537684716883825839.json'

# %% [markdown]
# ## User function

# %%
py_script = '/Users/damir/code/protocols/customers/pfizer/fc-topaz/protocols/create_correlations_dataframe.py'

# %%
user_function = tagbiopy.utils.load_function(py_script)

# %% [markdown]
# ## FC

# %%
fc = tagbiopy.utils.FC(filename_embed)

# %% [markdown]
# # Download expression dataframe

# %%
tag_data = tagbiopy.utils.TagbioData(url=fc.url, payload=fc.payload)

# %%
extension = 'html'
fig_path = 'test_' + now() + '.' + extension
tag_result = tagbiopy.utils.TagbioResult(extension='html', path=fig_path, path_mutable=False)

# %%
tag_result
# Out:
# <class TagbioResult: extension: html, path (private): test_17-53-17.html>

# %%
tag_result = user_function(tag_data, tag_result)

# %%
tag_result
# Out:
# <class TagbioResult: extension: html, fig: <class 'matplotlib.figure.Figure'>, path (private): test_17-53-17.html, dataframe shape: (20, 20)>

# %%
type(tag_result.fig)
# Out:
# matplotlib.figure.Figure

# %%
tag_result.fig.show()

# %%
tag_result.save()
# Out:
# ---------------------------------------------------------------------------
# TagbioPyError                             Traceback (most recent call last)
# <ipython-input-38-3437ca0cddcc> in <module>
# ----> 1 tag_result.save()
#
# ~/code/tagbiopy/tagbiopy/utils.py in save(self)
#     263             else:
#     264                 message = 'Please create a plotly figure and save it as html'
# --> 265                 raise TagbioPyError(message)
#     266         else:
#     267             if isinstance(self.fig, matplotlib.figure.Figure):
#
# TagbioPyError: Please create a plotly figure and save it as html

# %%
isinstance(tag_result.fig, plotly.graph_objects.Figure)

# %%
dir(tag_result.fig)

# %%
type(tag_result.fig)

# %%
isinstance(tag_result.fig, plotly.graph_objs.Figure)

# %%
help(tag_result.fig.write_image)
